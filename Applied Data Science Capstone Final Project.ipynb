# %% [markdown]
# # This notebook contains the code for my Capstone Project

# %%
import numpy as np
import pandas as pd
import bs4 as bs
import requests
pd.set_option("display.max_rows", 500, "display.max_columns", 500)
print("Package Installed")
# Out:
# Package Installed

# %% [markdown]
# ### Using the requests and bs4.beautifulSoup modules, I pull a HTML formatted file from the Canada postal code Wiki page and extracted the table from that file, Later converting it into a Dataframe.

# %%
website_url = requests.get("https://en.wikipedia.org/w/index.php?title=List_of_postal_codes_of_Canada:_M&oldid=1011037969").text

# %%
soup = bs.BeautifulSoup(website_url,"lxml")
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of postal codes of Canada: M - Wikipedia</title>
# ...

# %%
my_table = soup.find('table',{'class':'wikitable sortable'})

# %%
df=pd.read_html(str(my_table))
df=pd.DataFrame(df[0])
df
# Out:
#     Postal Code           Borough  \
# 0           M1A      Not assigned
# 1           M2A      Not assigned
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# 5           M6A        North York
# 6           M7A  Downtown Toronto
# 7           M8A      Not assigned
# 8           M9A         Etobicoke
# 9           M1B       Scarborough
# 10          M2B      Not assigned
# 11          M3B        North York
# 12          M4B         East York
# 13          M5B  Downtown Toronto
# 14          M6B        North York
# 15          M7B      Not assigned
# 16          M8B      Not assigned
# 17          M9B         Etobicoke
# 18          M1C       Scarborough
# 19          M2C      Not assigned
# 20          M3C        North York
# 21          M4C         East York
# 22          M5C  Downtown Toronto
# 23          M6C              York
# 24          M7C      Not assigned
# 25          M8C      Not assigned
# ...

# %% [markdown]
# ### We then proceeded to remove all the "Not assigned" classification from the Borough column.

# %%
df.drop(df.loc[df['Borough']=='Not assigned'].index, inplace=True)
df
# Out:
#     Postal Code           Borough  \
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# 5           M6A        North York
# 6           M7A  Downtown Toronto
# 8           M9A         Etobicoke
# 9           M1B       Scarborough
# 11          M3B        North York
# 12          M4B         East York
# 13          M5B  Downtown Toronto
# 14          M6B        North York
# 17          M9B         Etobicoke
# 18          M1C       Scarborough
# 20          M3C        North York
# 21          M4C         East York
# 22          M5C  Downtown Toronto
# 23          M6C              York
# 26          M9C         Etobicoke
# 27          M1E       Scarborough
# 30          M4E      East Toronto
# 31          M5E  Downtown Toronto
# 32          M6E              York
# 36          M1G       Scarborough
# 39          M4G         East York
# 40          M5G  Downtown Toronto
# 41          M6G  Downtown Toronto
# ...

# %%
clean_df = df.reset_index(drop=True)
clean_df
# Out:
#     Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# 5           M9A         Etobicoke
# 6           M1B       Scarborough
# 7           M3B        North York
# 8           M4B         East York
# 9           M5B  Downtown Toronto
# 10          M6B        North York
# 11          M9B         Etobicoke
# 12          M1C       Scarborough
# 13          M3C        North York
# 14          M4C         East York
# 15          M5C  Downtown Toronto
# 16          M6C              York
# 17          M9C         Etobicoke
# 18          M1E       Scarborough
# 19          M4E      East Toronto
# 20          M5E  Downtown Toronto
# 21          M6E              York
# 22          M1G       Scarborough
# 23          M4G         East York
# 24          M5G  Downtown Toronto
# 25          M6G  Downtown Toronto
# ...

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# ### We opted to use the pgeocode package to retrieve latitude and and longitude coordinates - METHOD 1

# %%
# !pip install pgeocode
print("Package Downloaded!")
# Out:
# ...
# Package Downloaded!

# %%
import pgeocode as pgcd

# %%
# Practice code to see it the pgeocode package worked
nomi = pgcd.Nominatim('ca')
lat = nomi.query_postal_code("M8W")
lat
# Out:
# postal_code                                       M8W
# country_code                                       CA
# place_name        Etobicoke (Alderwood / Long Branch)
# state_name                                    Ontario
# state_code                                         ON
# county_name                                 Etobicoke
# county_code                                       NaN
# community_name                                    NaN
# community_code                                    NaN
# latitude                                      43.6021
# longitude                                    -79.5402
# accuracy                                            6
# Name: 0, dtype: object

# %%
# Practice code to see it the pgeocode package worked
nomi = pgcd.Nominatim('ca')
lat = nomi.query_postal_code("M8W")["latitude"]
long = nomi.query_postal_code("M8W")["longitude"]
print(lat, ",",long)
# Out:
# 43.6021 , -79.5402

# %% [markdown]
# ### This part of the code adds the latitude and longitude by iterating through each row and identifying the postal code.

# %%
for lab, row in clean_df.iterrows():
    clean_df.loc[lab, "Latitude"] = nomi.query_postal_code(row["Postal Code"])["latitude"]
    clean_df.loc[lab, "Longitude"] = nomi.query_postal_code(row["Postal Code"])["longitude"]
clean_df
# Out:
#     Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# 5           M9A         Etobicoke
# 6           M1B       Scarborough
# 7           M3B        North York
# 8           M4B         East York
# 9           M5B  Downtown Toronto
# 10          M6B        North York
# 11          M9B         Etobicoke
# 12          M1C       Scarborough
# 13          M3C        North York
# 14          M4C         East York
# 15          M5C  Downtown Toronto
# 16          M6C              York
# 17          M9C         Etobicoke
# 18          M1E       Scarborough
# 19          M4E      East Toronto
# 20          M5E  Downtown Toronto
# 21          M6E              York
# 22          M1G       Scarborough
# 23          M4G         East York
# 24          M5G  Downtown Toronto
# 25          M6G  Downtown Toronto
# ...

# %%
clean_df.columns
# Out:
# Index(['Postal Code', 'Borough', 'Neighbourhood', 'Latitude', 'Longitude'], dtype='object')

# %%
clean_df.shape
# Out:
# (103, 5)

# %% [markdown]
# ### We opted to use the pd.read_csv() to retrieve latitude and and longitude coordinates from file shared in the project submission page- METHOD 2

# %%
lat_and_long = pd.read_csv('https://cocl.us/Geospatial_data')
lat_and_long.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
clean_df2 = pd.merge(df,lat_and_long,on='Postal Code')
clean_df2.head()
# Out:
#   Postal Code           Borough                                Neighbourhood  \
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494

# %%
clean_df2.shape
# Out:
# (103, 5)

# %% [markdown]
# ### Visualizing all the Neighborhoods and clustering them

# %%
from sklearn.cluster import KMeans
from geopy.geocoders import Nominatim
print("Package Downloaded!")
# !pip install folium
import folium
print("Complete!")
# Out:
# Package Downloaded!
# ...
# Complete!

# %%
address = 'Toronto, CA'

geolocator = Nominatim(user_agent="toronto_explorer")
tor_location = geolocator.geocode(address)
tor_latitude = tor_location.latitude
tor_longitude = tor_location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(tor_latitude, tor_longitude))
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.

# %% [markdown]
# ### Method 1: Mapping (Did not work due to what I believe is a lack of precision for its latitude and longitude)

# %%
# create map of Manhattan using latitude and longitude values
map_toronto = folium.Map(location=[tor_latitude, tor_longitude], zoom_start=11)

for lat, lng, label in zip(clean_df['Latitude'], clean_df['Longitude'], clean_df['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto) 
 
    
map_toronto
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-117-a9db55ee1bda> in <module>
#      12         fill_color='#3186cc',
#      13         fill_opacity=0.7,
# ---> 14         parse_html=False).add_to(map_toronto)
#      15
#      16
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/folium/vector_layers.py in __init__(self, location, radius, popup, tooltip, **kwargs)
#     303     def __init__(self, location=None, radius=10, popup=None, tooltip=None, **kwargs):
#     304         super(CircleMarker, self).__init__(location, popup=popup,
# --> 305                                            tooltip=tooltip)
#     306         self._name = 'CircleMarker'
#     307         self.options = path_options(line=False, radius=radius, **kwargs)
#
# ...

# %%
### Method 2: Mapping (Did work due to what I believe is more precision for its latitude and longitude)

# %%
# create map of Manhattan using latitude and longitude values
map_toronto2 = folium.Map(location=[tor_latitude, tor_longitude], zoom_start=11)

for lat, lng, label in zip(clean_df2['Latitude'], clean_df2['Longitude'], clean_df2['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto2) 
 
    
map_toronto2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ## Initializing K-mean algorithm to cluster neighbourhoods based on distance from eachother.

# %% [markdown]
# #### Dropping the categorical columns first, then running the K-mean algorithm

# %%
clustering_table = clean_df2.drop(['Postal Code','Borough','Neighbourhood'],axis = 1)
clustering_table
# Out:
#       Latitude  Longitude  Label
# 0    43.753259 -79.329656      3
# 1    43.725882 -79.315572      3
# 2    43.654260 -79.360636      2
# 3    43.718518 -79.464763      4
# 4    43.662301 -79.389494      2
# 5    43.667856 -79.532242      0
# 6    43.806686 -79.194353      1
# 7    43.745906 -79.352188      5
# 8    43.706397 -79.309937      3
# 9    43.657162 -79.378937      2
# 10   43.709577 -79.445073      4
# 11   43.650943 -79.554724      0
# 12   43.784535 -79.160497      1
# 13   43.725900 -79.340923      3
# 14   43.695344 -79.318389      3
# 15   43.651494 -79.375418      2
# 16   43.693781 -79.428191      4
# 17   43.643515 -79.577201      0
# 18   43.763573 -79.188711      1
# 19   43.676357 -79.293031      3
# 20   43.644771 -79.373306      2
# 21   43.689026 -79.453512      4
# 22   43.770992 -79.216917      1
# 23   43.709060 -79.363452      3
# 24   43.657952 -79.387383      2
# 25   43.669542 -79.422564      2
# 26   43.773136 -79.239476      1
# ...

# %%
k = 7
k_means = KMeans(init="k-means++", n_clusters=k, n_init=12)
k_means.fit(clustering_table)
clustering_labels = k_means.labels_
clustering_labels
# Out:
# array([3, 3, 2, 4, 2, 0, 1, 5, 3, 2, 4, 0, 1, 3, 3, 2, 4, 0, 1, 3, 2, 4,
#        1, 3, 2, 2, 1, 5, 5, 3, 2, 4, 1, 5, 6, 3, 2, 2, 1, 5, 4, 3, 2, 2,
#        3, 5, 6, 3, 2, 4, 6, 1, 5, 6, 3, 5, 4, 6, 3, 5, 6, 5, 5, 4, 6, 1,
#        5, 5, 2, 4, 6, 1, 5, 5, 2, 4, 0, 6, 1, 2, 2, 4, 1, 2, 2, 1, 2, 2,
#        0, 6, 1, 2, 2, 0, 6, 1, 2, 2, 0, 2, 3, 0, 0], dtype=int32)

# %%
clean_df2["Label"] = clustering_labels
clean_df2
# Out:
#     Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# 5           M9A         Etobicoke
# 6           M1B       Scarborough
# 7           M3B        North York
# 8           M4B         East York
# 9           M5B  Downtown Toronto
# 10          M6B        North York
# 11          M9B         Etobicoke
# 12          M1C       Scarborough
# 13          M3C        North York
# 14          M4C         East York
# 15          M5C  Downtown Toronto
# 16          M6C              York
# 17          M9C         Etobicoke
# 18          M1E       Scarborough
# 19          M4E      East Toronto
# 20          M5E  Downtown Toronto
# 21          M6E              York
# 22          M1G       Scarborough
# 23          M4G         East York
# 24          M5G  Downtown Toronto
# 25          M6G  Downtown Toronto
# ...

# %%
# To add color for identifying clusters easier
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
map_toronto2_cluster = folium.Map(location=[tor_latitude, tor_longitude], zoom_start=11)

x = np.arange(k)
ys = [i + x + (i*x)**2 for i in range(k)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

markers_colors = []
for lat, lng, label, cluster in zip(clean_df2['Latitude'], clean_df2['Longitude'], clean_df2['Neighbourhood'], clean_df2['Label']):
    label = folium.Popup(str(label) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_toronto2_cluster)
map_toronto2_cluster
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
